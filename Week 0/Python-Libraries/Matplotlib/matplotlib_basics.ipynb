# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create the plot
plt.plot(x, y)

# Add labels and title
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Simple Line Plot")

# Show the plot
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]
y2 = [1, 2, 3, 4, 5]

# Plot multiple lines
plt.plot(x, y1, label="y = x^2", color="blue", linestyle="--", marker="o")
plt.plot(x, y2, label="y = x", color="red", linestyle="-.", marker="s")

# Add labels, legend, and title
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Multiple Line Plot")
plt.legend()

# Show the plot
plt.show()

# %%
# Data
x = [1, 2, 3, 4, 5]
y = [5, 7, 6, 8, 7]

# Create scatter plot
plt.scatter(x, y, color="green", marker="x", s=100)

# Add labels and title
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Scatter Plot")

# Show the plot
plt.show()

# %%
# Data
categories = ["A", "B", "C", "D"]
values = [10, 20, 15, 25]

# Create bar chart
plt.bar(categories, values, color="purple")

# Add labels and title
plt.xlabel("Categories")
plt.ylabel("Values")
plt.title("Bar Chart")

# Show the plot
plt.show()

# %%
# Create horizontal bar chart
plt.barh(categories, values, color="orange")

# Add labels and title
plt.xlabel("Values")
plt.ylabel("Categories")
plt.title("Horizontal Bar Chart")

# Show the plot
plt.show()

# %%
# Data
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5, 5]

# Create histogram
plt.hist(data, bins=5, color="purple", edgecolor="orange")

# Add labels and title
plt.xlabel("Bins")
plt.ylabel("Frequency")
plt.title("Histogram")

# Show the plot
plt.show()

# %%
# Data
labels = ["Python", "Java", "C++", "JavaScript"]
sizes = [40, 30, 20, 10]
colors = ["gold", "lightblue", "lightgreen", "pink"]
explode = (0.1, 0.05, 0.05, 0.05)  # Highlight the first slice

# Create pie chart
plt.pie(sizes, labels=labels, colors=colors, explode=explode, autopct="%1.1f%%", shadow=True)

# Add title
plt.title("Programming Language Popularity")

# Show the plot
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create the plot
plt.plot(x, y, color="red", linewidth=2, linestyle="--", marker="o", markersize=8)

# Add grid, labels, and title
plt.grid(True, linestyle="--", alpha=0.5)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Customized Plot")

# Show the plot
plt.show()

# %%
# Data
x = [1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]
y2 = [2, 4, 6, 8, 10]

# Create subplots
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st plot
plt.plot(x, y1, color="blue")
plt.title("Plot 1")

plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd plot
plt.plot(x, y2, color="green")
plt.title("Plot 2")

# Show the plots
plt.tight_layout()
plt.show()

# %%
# Data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create plot
plt.plot(x, y)
plt.title("Save Plot Exaplte")

# Save the plot
plt.savefig("plot_exaplte.png")

# Show the plot
plt.show()

# %% [markdown]
# ### Some assignment problems

# %%
# Assignment 1
'''
Create a numpy array of length 1000 which resembles a normal distribution with mean 0 and standard deviation 1.
Create 2 subplots both histograms with 20 bins side by side, one which has a beta (a=2, b=5) distribution, the other which has the normal distribution.
'''
# Out:
# '\nCreate a numpy array of length 1000 which resembles a normal distribution with mean 0 and standard deviation 1.\nCreate 2 subplots both histograms with 20 bins side by side, one which has a beta (a=2, b=5) distribution, the other which has the normal distribution.\n'

# %%
# TODO
import numpy as np
# import matplotlib as plt

array_normal=np.random.normal(loc=0,scale=1,size=1000)
array_beta =np.random.beta(2,5,1000)

plt.figure(figsize=(15, 5))

plt.subplot(1,2,1)

plt.hist(array_normal, bins=20,density=True,alpha=0.6, color="purple", edgecolor="orange",label="Histogram")
plt.xlabel("Bins")
plt.ylabel("Frequency")
plt.title("Histogram with Normal Distribution")

plt.subplot(1,2,2)

plt.hist(array_beta, bins=20,density=True,alpha=0.6, color="orange", edgecolor="purple",label="Histogram")
plt.xlabel("Bins")
plt.ylabel("Frequency")
plt.title("Histogram with Beta Distribution")



plt.show()

# %%
# Assignment 2
'''
Generate a NumPy array of 1000 random values drawn from a normal distribution with mean 0 and std. dev 1
Plot a histogram of the data with 20 bins.
Add vertical lines to indicate the mean of the data, the 25th percentile and the 75th percentile.
Annotate the plot with labels for the mean, 25th percentile, and 75th percentile.
Customize the visualization (light pink colour scheme, titles, labels, legend).
'''
# Out:
# '\nGenerate a NumPy array of 1000 random values drawn from a normal distribution with mean 0 and std. dev 1\nPlot a histogram of the data with 20 bins.\nAdd vertical lines to indicate the mean of the data, the 25th percentile and the 75th percentile.\nAnnotate the plot with labels for the mean, 25th percentile, and 75th percentile.\nCustomize the visualization (light pink colour scheme, titles, labels, legend).\n'

# %%
# TODO
import numpy as np
import statistics
# import matplotlib as plt

array_normal=np.random.normal(loc=0,scale=1,size=1000)

plt.hist(array_normal, bins=20,density=True,alpha=0.6, color="pink", edgecolor="black",label="normal distribution")
plt.axvline(np.mean(array_normal),color='orange',linestyle='dashed',linewidth=2)
plt.annotate('mean',xy=(np.mean(array_normal),0), xytext=(-2, -0.08), arrowprops=dict(facecolor='black', shrink=0.05), color = "orange")
plt.axvline(np.percentile(array_normal,25),color='red',linestyle='dashed',linewidth=1)
plt.annotate('25th percentile',xy=(np.percentile(array_normal,25),0), xytext=(-2, 0.1), arrowprops=dict(facecolor='black', shrink=0.0005), color = "red")
plt.axvline(np.percentile(array_normal,75),color='purple',linestyle='dashed',linewidth=1)
plt.annotate('75 percentile',xy=(np.percentile(array_normal,75),0), xytext=(2, 0.2), arrowprops=dict(facecolor='black', shrink=0.0005), color = "purple")
plt.xlabel("Bins")
plt.ylabel("Frequency")
plt.title("Histogram with Normal Distribution")
plt.legend()
plt.show()
